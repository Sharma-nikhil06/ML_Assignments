# %%
# Question 1
import numpy as np
arr=np.random.random((10,1))
print(arr.shape)
print(np.mean(arr))
# Out:
# (10, 1)
# 0.521243016756492

# %%
# Question 2
ar=np.random.random((20,1))
print("Variance",(np.std(ar))**2)
print("STD",np.std(ar))
# Out:
# Variance 0.08268036669541114
# STD 0.2875419390200517

# %%
# Question 3
A=np.random.random((10,20))
B=np.random.random((20,25))
c=np.matmul(A,B)
print(c)
print(np.sum(c))
# Out:
# [[6.72246189 6.02335002 4.67300539 4.90336725 4.97220282 5.86050918
#   4.71070992 4.7009154  5.71335966 3.3991963  4.36354532 3.84448597
#   4.95330337 5.33032006 5.28459738 4.97256886 5.6653158  4.81498203
#   4.38923063 4.38878947 4.18642041 5.38534232 4.50151767 6.14184859
#   4.68272459]
#  [5.14854255 4.77313247 3.59458431 4.30458646 3.83223195 4.78301169
#   4.26298476 3.96088546 4.43957603 3.55702262 4.05861735 3.79265114
#   4.18611254 5.16612976 4.27614739 4.33668125 4.18081151 3.63235627
#   3.77538063 4.02993328 3.91374969 4.16314835 4.09436292 5.14542887
#   3.08189415]
#  [4.97162532 4.92880729 3.61504325 3.64523566 3.91355414 4.41448405
#   3.70895289 3.97113563 3.95148647 3.64598394 4.05269885 3.6925614
#   3.91790477 5.14049391 4.5250785  6.16119248 3.99096265 4.36024143
#   4.11144348 4.70409921 3.03049139 4.15635961 4.70852648 5.07185573
#   3.82405996]
#  [7.14352852 6.09611274 5.41960329 5.230896   5.80280742 6.55906637
# ...

# %%
# Question 4

# %%
A=np.random.random((10,1))

# %%
print(A)
# Out:
# [[0.94989676]
#  [0.10992297]
#  [0.56196113]
#  [0.96724479]
#  [0.00279303]
#  [0.26197621]
#  [0.15113024]
#  [0.17965825]
#  [0.8028184 ]
#  [0.33986448]]

# %%
def fun(x):
    return (1/(1+ np.exp(-x)))
for i in range(10):
    print(fun(A[i]))
# Out:
# [0.72109441]
# [0.5274531]
# [0.63690619]
# [0.72456999]
# [0.50069826]
# [0.56512202]
# [0.53771081]
# [0.54479414]
# [0.69057704]
# [0.5841576]
